-- %% [markdown]
-- DROP TABLE FROM `BRONZE` LAYER
-- - `ORACLE_HRMS.BRONZE.LOCATIONS`

-- %%
DROP TABLE IF EXISTS ORACLE_HRMS.BRONZE.LOCATIONS

-- %%
-- DROP AUDIT TABLE
DROP TABLE IF EXISTS ORACLE_HRMS.AUDIT.AUDIT_LOGS;
