-- %% [markdown]
-- ### CREATE `BRONZE TABLE`

-- %%
-- CREATE ORACLE_HRMS.BRONZE.LOCATIONS
CREATE TABLE IF NOT EXISTS oracle_hrms.bronze.locations
(
    location_id INT,
    location_name STRING,
    load_ts STRING,
    file_path STRING,
    file_name STRING,
    load_timestamp TIMESTAMP
)
